# %% [markdown]
# ## 数据获取

# %%
import QUANTAXIS as QA
# Out:
# QUANTAXIS>> start QUANTAXIS
# QUANTAXIS>> Welcome to QUANTAXIS, the Version is 1.0.68
# QUANTAXIS>>
#  ````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````
#   ``########`````##````````##``````````##`````````####````````##```##########````````#``````##``````###```##`````######``
#   `##``````## ```##````````##`````````####````````##`##```````##```````##```````````###``````##````##`````##```##`````##`
#   ##````````##```##````````##````````##`##````````##``##``````##```````##``````````####```````#```##``````##```##``````##
#   ##````````##```##````````##```````##```##```````##```##`````##```````##`````````##`##```````##`##```````##````##```````
#   ##````````##```##````````##``````##`````##``````##````##````##```````##````````##``###```````###````````##`````##``````
#   ##````````##```##````````##``````##``````##`````##`````##```##```````##```````##````##```````###````````##``````###````
# ...

# %% [markdown]
# * 股票列表

# %%
#数据库 获取数据
syms=QA.QA_fetch_stock_list_adv()
syms.head()
# Out:
#      code  decimal_point  name    pre_close       sec sse  volunit
# 0  000001              2  平安银行   200.030000  stock_cn  sz      100
# 1  000002              2  万 科Ａ    22.719999  stock_cn  sz      100
# 2  000004              2  国农科技    18.580000  stock_cn  sz      100
# 3  000005              2  世纪星源  3906.006875  stock_cn  sz      100
# 4  000006              2  深振业Ａ     5.460000  stock_cn  sz      100

# %%
#从tdx获取数据
futs=QA.QA_fetch_get_future_list('tdx')
futs.head()
# Out:
#        category  market   code    name   desc
# code
# J1902         3      29  J1902  焦炭1902  J1902
# J1903         3      29  J1903  焦炭1903  J1903
# J1904         3      29  J1904  焦炭1904  J1904
# J1905         3      29  J1905  焦炭1905  J1905
# J1906         3      29  J1906  焦炭1906  J1906

# %%
min1=QA.QA_fetch_get_stock_min('tdx','000001','2017-07-01','2017-08-01','5min')

# %%
min1[['open','close']].plot()

# %%
real=QA.QA_fetch_get_stock_realtime('tdx',['000001','000002'])

# %%
real
# Out:
#                          datetime  active1  active2  last_close    code  \
# code
# 000001 2018-08-22 21:27:30.517382     4288     4288        9.23  000001
# 000002 2018-08-22 21:27:30.517382     4373     4373       23.91  000002
#
#          open   high    low  price  cur_vol    ...      bid3  bid_vol3   ask4  \
# code                                           ...
# 000001   9.24   9.34   9.13   9.29     8769    ...      9.26      2906   9.32
# 000002  23.91  24.08  23.67  23.92     6354    ...     23.90      1022  23.96
#
#         ask_vol4   bid4  bid_vol4   ask5  ask_vol5   bid5  bid_vol5
# code
# 000001      9665   9.25      5020   9.33     12373   9.24      3138
# 000002       318  23.89       317  23.97       454  23.88       404
#
# [2 rows x 33 columns]

# %% [markdown]
# * 板块数据

# %%
block=QA.QA_fetch_stock_block_adv()

# %%
block.data.head()
# Out:
#                  source type
# blockname code
# 通达信88     000001    tdx   gn
#           000002    tdx   gn
#           000008    tdx   gn
#           000028    tdx   gn
#           000157    tdx   gn

# %%
QA.QA_fetch_financial_report?

# %%
res=QA.QA_fetch_financial_report(['000001','600100'],['2017-03-31','2017-06-30','2017-09-31','2017-12-31','2018-03-31'])

# %%
res
# Out:
#                        EPS  deductEPS  undistributedProfitPerShare  \
# report_date code
# 2017-03-31  000001  0.3100     0.3100                         4.05
# 2017-06-30  000001  0.6800     0.6800                         4.26
# 2017-12-31  000001  1.3000     1.3000                         4.64
# 2018-03-31  000001  0.3300     0.3300                         4.69
# 2017-03-31  600100 -0.0908    -0.1030                         2.57
# 2017-06-30  600100 -0.0407    -0.0598                         2.37
# 2017-12-31  600100  0.0350    -0.0115                         2.45
# 2018-03-31  600100 -0.0756    -0.0871                         2.37
#
#                     netAssetsPerShare  capitalReservePerShare     ROE  \
# report_date code
# 2017-03-31  000001            10.9400                    3.29   2.992
# 2017-06-30  000001            11.1500                    3.29   6.100
# 2017-12-31  000001            11.7706                    3.29  11.474
# ...

# %%
QA.QA_fetch_financial_report_adv?

# %%
res_adv=QA.QA_fetch_financial_report_adv('000001','2017-01-01','2018-05-01')

# %%
res
# Out:
#                        EPS  deductEPS  undistributedProfitPerShare  \
# report_date code
# 2017-03-31  000001  0.3100     0.3100                         4.05
# 2017-06-30  000001  0.6800     0.6800                         4.26
# 2017-12-31  000001  1.3000     1.3000                         4.64
# 2018-03-31  000001  0.3300     0.3300                         4.69
# 2017-03-31  600100 -0.0908    -0.1030                         2.57
# 2017-06-30  600100 -0.0407    -0.0598                         2.37
# 2017-12-31  600100  0.0350    -0.0115                         2.45
# 2018-03-31  600100 -0.0756    -0.0871                         2.37
#
#                     netAssetsPerShare  capitalReservePerShare     ROE  \
# report_date code
# 2017-03-31  000001            10.9400                    3.29   2.992
# 2017-06-30  000001            11.1500                    3.29   6.100
# 2017-12-31  000001            11.7706                    3.29  11.474
# ...

# %%
import QUANTAXIS as QA
# Out:
# QUANTAXIS>> start QUANTAXIS
# QUANTAXIS>> Welcome to QUANTAXIS, the Version is 1.0.68
# QUANTAXIS>>
#  ````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````
#   ``########`````##````````##``````````##`````````####````````##```##########````````#``````##``````###```##`````######``
#   `##``````## ```##````````##`````````####````````##`##```````##```````##```````````###``````##````##`````##```##`````##`
#   ##````````##```##````````##````````##`##````````##``##``````##```````##``````````####```````#```##``````##```##``````##
#   ##````````##```##````````##```````##```##```````##```##`````##```````##`````````##`##```````##`##```````##````##```````
#   ##````````##```##````````##``````##`````##``````##````##````##```````##````````##``###```````###````````##`````##``````
#   ##````````##```##````````##``````##``````##`````##`````##```##```````##```````##````##```````###````````##``````###````
# ...

# %%
class config:

    start='2010-01-01'
    end='2018-08-01'
    code='000001'
c=config()

# %%
stock1=QA.QA_fetch_stock_day_adv(c.code,c.start,c.end)

# %%
stock1
# Out:
# < QA_DataStruct_Stock_day with 1 securities >

# %%
import  matplotlib.pyplot as plt

# %%
stock1.date
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2018-07-19', '2018-07-20', '2018-07-23', '2018-07-24',
#                '2018-07-25', '2018-07-26', '2018-07-27', '2018-07-30',
#                '2018-07-31', '2018-08-01'],
#               dtype='datetime64[ns]', name='date', length=2016, freq=None)

# %%
stock1.volume
# Out:
# date        code
# 2010-01-04  000001     241922.0
# 2010-01-05  000001     556499.0
# 2010-01-06  000001     412143.0
# 2010-01-07  000001     355336.0
# 2010-01-08  000001     288543.0
# 2010-01-11  000001     442846.0
# 2010-01-12  000001     591795.0
# 2010-01-13  000001     935039.0
# 2010-01-14  000001     521194.0
# 2010-01-15  000001     539508.0
# 2010-01-18  000001     349126.0
# 2010-01-19  000001     650715.0
# 2010-01-20  000001     490835.0
# 2010-01-21  000001     632301.0
# 2010-01-22  000001     882538.0
# 2010-01-25  000001     356058.0
# 2010-01-26  000001     345325.0
# 2010-01-27  000001     401034.0
# 2010-01-28  000001     262132.0
# 2010-01-29  000001     240688.0
# 2010-02-01  000001     283179.0
# 2010-02-02  000001     286733.0
# 2010-02-03  000001     549005.0
# 2010-02-04  000001     303346.0
# 2010-02-05  000001     276174.0
# 2010-02-08  000001     206423.0
# 2010-02-09  000001     248170.0
# 2010-02-10  000001     253839.0
# ...

# %%
plt.plot_date(stock1.date,stock1.amount)

# %%
stock1.amount.plot()

# %%
exchange=QA.QA_fetch_get_exchangerate_day('tdx',c.code,c.start,c.end)
# Out:
# QUANTAXIS>> Selecting the Best Server IP of TDX
# BAD RESPONSE 218.108.98.244
# DEFAULT STOCK IP is BAD, RETESTING
# BAD RESPONSE 114.80.80.222
# BAD RESPONSE 123.125.108.24
# BAD RESPONSE 123.125.108.23
# BAD RESPONSE 218.75.126.9
# BAD RESPONSE 115.238.90.165
# BAD RESPONSE 124.160.88.183
# BAD RESPONSE 60.12.136.250
# BAD RESPONSE 218.108.98.244
# BAD RESPONSE 218.108.47.69
# BAD RESPONSE 180.153.39.51
# BAD RESPONSE 121.14.2.7
# BAD RESPONSE 60.28.29.69
# BAD RESPONSE 180.153.18.170
# BAD RESPONSE 180.153.18.171
# BAD RESPONSE 180.153.18.17
# BAD RESPONSE 61.135.142.73
# BAD RESPONSE 115.238.56.198
# BAD RESPONSE 60.191.117.167
# BAD RESPONSE hq.cjis.cn
# BAD RESPONSE 59.173.18.69
# BAD RESPONSE sztdx.gtjas.com
# BAD RESPONSE jstdx.gtjas.com
# BAD RESPONSE shtdx.gtjas.com
# BAD RESPONSE 218.9.148.108
# BAD RESPONSE 61.153.144.179
# BAD RESPONSE 61.153.209.138
# BAD RESPONSE 61.153.209.139
# BAD RESPONSE hq1.daton.com.cn
# BAD RESPONSE 119.29.51.30
# BAD RESPONSE 114.67.61.70
# ...

# %%
exchange.head()
# Out:
#              open   high    low  close  position  trade  price        date  \
# date
# 2010-01-04  1.469  1.469  1.469  1.469         0      0    0.0  2010-01-04
# 2010-01-05  1.476  1.476  1.476  1.476         0      0    0.0  2010-01-05
# 2010-01-06  1.470  1.470  1.470  1.470         0      0    0.0  2010-01-06
# 2010-01-07  1.443  1.443  1.443  1.443         0      0    0.0  2010-01-07
# 2010-01-08  1.447  1.447  1.447  1.447         0      0    0.0  2010-01-08
#
#               code    date_stamp
# date
# 2010-01-04  000001  1.262534e+09
# 2010-01-05  000001  1.262621e+09
# 2010-01-06  000001  1.262707e+09
# 2010-01-07  000001  1.262794e+09
# 2010-01-08  000001  1.262880e+09

# %%
exchange.open.plot()

# %%
symbols=QA.QA_fetch_stock_list_adv()

# %%
blockss=QA.QA_fetch_stock_block_adv()

# %%
QA.QA_fetch_index_day_adv?

# %%
QA.QA_fetch_index_day?

# %%
indexs=QA.QA_fetch_index_day('600085',c.start,c.end)

# %%
data=QA.QAFetch.QATdx.QA_fetch_get_index_min('000001','2017-07-01','2017-08-01','15min')

# %%
blockss.data
# Out:
#                  source   type
# blockname code
# 通达信88     000001    tdx     gn
#           000002    tdx     gn
#           000008    tdx     gn
#           000028    tdx     gn
#           000157    tdx     gn
#           000333    tdx     gn
#           000425    tdx     gn
#           000531    tdx     gn
#           000538    tdx     gn
#           000703    tdx     gn
#           000776    tdx     gn
#           000837    tdx     gn
#           000876    tdx     gn
#           000895    tdx     gn
#           000900    tdx     gn
#           000970    tdx     gn
#           000996    tdx     gn
#           002033    tdx     gn
#           002039    tdx     gn
#           002051    tdx     gn
#           002186    tdx     gn
#           002236    tdx     gn
#           002293    tdx     gn
#           002310    tdx     gn
#           002315    tdx     gn
#           002371    tdx     gn
#           002422    tdx     gn
#           002456    tdx     gn
# ...

# %%
len(blockss.block_name)
# Out:
# 542

# %%
symbols
# Out:
#         code  decimal_point  name    pre_close       sec sse  volunit
# 0     000001              2  平安银行   312.042500  stock_cn  sz      100
# 1     000002              2  万 科Ａ    23.910000  stock_cn  sz      100
# 2     000004              2  国农科技    18.410000  stock_cn  sz      100
# 3     000005              2  世纪星源  3970.011250  stock_cn  sz      100
# 4     000006              2  深振业Ａ     5.510000  stock_cn  sz      100
# 5     000007              2   全新好  1256.005000  stock_cn  sz      100
# 6     000008              2  神州高铁  6978.006875  stock_cn  sz      100
# 7     000009              2  中国宝安     4.670000  stock_cn  sz      100
# 8     000010              2  美丽生态     4.510000  stock_cn  sz      100
# 9     000011              2  深物业A   840.060000  stock_cn  sz      100
# 10    000012              2  南 玻Ａ     4.930000  stock_cn  sz      100
# 11    000014              2  沙河股份   760.042500  stock_cn  sz      100
# ...

# %%
mins=QA.QAFetch.QATdx.QA_fetch_get_stock_min('000002','2017-07-01','2017-08-01','5min')

# %%
mins
# Out:
#                       open  close   high    low        vol      amount  \
# datetime
# 2017-07-03 09:35:00  24.76  24.91  24.98  24.68  2569600.0  63707448.0
# 2017-07-03 09:40:00  24.91  25.02  25.18  24.85  1806200.0  45223752.0
# 2017-07-03 09:45:00  25.00  24.88  25.07  24.87  1272900.0  31804256.0
# 2017-07-03 09:50:00  24.89  24.79  24.94  24.79  1087200.0  27033408.0
# 2017-07-03 09:55:00  24.79  24.82  24.92  24.79   769200.0  19105056.0
# 2017-07-03 10:00:00  24.82  24.97  24.98  24.82   795600.0  19805472.0
# 2017-07-03 10:05:00  24.97  24.86  24.97  24.84   919100.0  22891744.0
# 2017-07-03 10:10:00  24.86  24.70  24.87  24.70  1796500.0  44468640.0
# 2017-07-03 10:15:00  24.70  24.68  24.78  24.68  1588600.0  39263584.0
# 2017-07-03 10:20:00  24.68  24.69  24.74  24.65  1427100.0  35219232.0
# 2017-07-03 10:25:00  24.69  24.50  24.71  24.49  3333900.0  81950528.0
# 2017-07-03 10:30:00  24.50  24.44  24.57  24.37  3195400.0  78096576.0
# ...

# %%
mins[['open','amount']]['2017-07-06'].corr()
# Out:
#             open    amount
# open    1.000000  0.114912
# amount  0.114912  1.000000

# %%
mins.open.plot()
